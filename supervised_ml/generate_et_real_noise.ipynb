# %%
import matplotlib.pyplot as plt
from blimpy import Waterfall

# %matplotlib inline

# %%
# Load header only
fb = Waterfall('/datax/scratch/jaym/data0005-beam0000.fil')
fb.info()

# Plot before injection
plt.figure(figsize=(10, 6))
fb.plot_waterfall()
plt.title('Before Injection')
plt.tight_layout()
# Out:
# --- File Info ---
#       machine_id :                                0
#     telescope_id :                               -1
#          src_raj :                 9:01:22.45000009
#          src_dej :                18:14:31.50000209
#         az_start :                              0.0
#         za_start :                              0.0
#        data_type :                                1
#             fch1 :           2883.4999990463257 MHz
#             foff :         -1.9073486328125e-06 MHz
#           nchans :                         16777216
#           nbeams :                                1
#            ibeam :                                0
#            nbits :                               32
#    tstart (ISOT) :          2024-10-11T16:30:58.858
#     tstart (MJD) :                60594.68818123033
#            tsamp :                         0.524288
#             nifs :                                1
#      barycentric :                                1
#    pulsarcentric :                                1
#      source_name :                     PHASE_CENTER
#      rawdatafile : /mnt/cosmic-storage-1/data3/vla_target_keepraw/24A-343.sb46001740.eb46901750.60
#
# Num ints in file :                               32
#       File shape :                (32, 1, 16777216)
# --- Selection Info ---
# Data selection shape :                (32, 1, 16777216)
# Minimum freq (MHz) :               2851.5000009536743
# Maximum freq (MHz) :               2883.4999990463257
